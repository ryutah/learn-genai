# %%
# %%capture --no-stderr
# %pip install -U langgraph langchain_experimental langchain-google-vertexai pydantic==2.9.1

# %%
from typing import Annotated

from langchain_core.tools import tool
from langchain_experimental.utilities import PythonREPL

repl = PythonREPL()

@tool
def python_repl_tool(
    code: Annotated[str, "The python code to execute to generate your chart."],
):
    """
    Use this to execute python code and do math. If you want to see the output of a value,
    you should print it out with `print(...)`. This is visible to the user.
    """
    try:
        result = repl.run(code)
    except BaseException as e:
        return f"Failed to execute. Error: {repr(e)}"
    result_str = f"Successfully executed:\n```python\n{code}\n```\nStdout: {result}"
    return result_str

# %% [markdown]
# # Create Agent Supervisor

# %%
from langgraph.graph import MessagesState

# The agent state is the input to each node in the graph
class AgentState(MessagesState):
    # The 'next' field indicates where to route to next
    next: str

# %%
from typing import Literal
from typing_extensions import TypedDict

from langgraph.graph import END
from langchain_google_vertexai import ChatVertexAI

members = ["researcher", "coder"]
# Our team supervisor is an LLM node. It just picks the next agent to process
# and decides when the work is completed
options = members + ["FINISH"]

system_prompt = (
    "You are a supervisor tasked with managing a conversation between the"
    f" following workers: {members}. Given the following user request,"
    " respond with the worker to act next. Each worker will perform a"
    " task and respond with their results and status. When finished,"
    " respond with FINISH."
)

class Router(TypedDict):
    """Worker to route to next. If no workers needed, route to FINISH."""

    next: Literal[*options]

llm = ChatVertexAI(model_name="gemini-1.5-flash-001")

def supervisor_node(state: AgentState) -> AgentState:
    messages = [
        {"role": "system", "content": system_prompt},
    ] + state["messages"]
    response = llm.with_structured_output(Router).invoke(messages)
    next_ = response["next"]
    if next_ == "FINISH":
        next_ = END

    return {"next": next_}

# %% [markdown]
# # Construct Graph

# %%
from langchain_core.messages import HumanMessage
from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import create_react_agent


research_agent = create_react_agent(
    llm, tools=[], state_modifier="You are a researcher. DO NOT do any math."
)


def research_node(state: AgentState) -> AgentState:
    result = research_agent.invoke(state)
    return {
        "messages": [
            HumanMessage(content=result["messages"][-1].content, name="researcher")
        ]
    }


# NOTE: THIS PERFORMS ARBITRARY CODE EXECUTION, WHICH CAN BE UNSAFE WHEN NOT SANDBOXED
code_agent = create_react_agent(llm, tools=[python_repl_tool])


def code_node(state: AgentState) -> AgentState:
    result = code_agent.invoke(state)
    return {
        "messages": [HumanMessage(content=result["messages"][-1].content, name="coder")]
    }


builder = StateGraph(AgentState)
builder.add_edge(START, "supervisor")
builder.add_node("supervisor", supervisor_node)
builder.add_node("researcher", research_node)
builder.add_node("coder", code_node)

# %%
for member in members:
    builder.add_edge(member, "supervisor")

builder.add_conditional_edges("supervisor", lambda state: state["next"])
builder.add_edge(START, "supervisor")

graph = builder.compile()

# %%
from IPython.display import display, Image

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
for s in graph.stream(
    {"messages": [("user", "What's the square root of 42?")]}, subgraphs=True
):
    print(s)
    print("----")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for s in graph.stream(
#       2     {"messages": [("user", "What's the square root of 42?")]}, subgraphs=True
#       3 ):
#       4     print(s)
#       5     print("----")
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1647, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1641     # Similarly to Bulk Synchronous Parallel / Pregel model
#    1642     # computation proceeds in steps, while there are channel updates
#    1643     # channel updates from step N are only visible in step N+1
#    1644     # channels are guaranteed to be immutable for the duration of the step,
#    1645     # with channel updates applied only at the transition between steps
#    1646     while loop.tick(input_keys=self.input_channels):
# -> 1647         for _ in runner.tick(
#    1648             loop.tasks.values(),
#    1649             timeout=self.step_timeout,
#    1650             retry_policy=self.retry_policy,
#    1651             get_waiter=get_waiter,
#    1652         ):
#    1653             # emit output
#    1654             yield from output()
#    1655 # emit output
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langgraph/pregel/runner.py:159, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     157     yield
#     158 # panic on failure or timeout
# --> 159 _panic_or_proceed(
#     160     done_futures.union(f for f, t in futures.items() if t is not None),
#     161     panic=reraise,
#     162 )
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langgraph/pregel/runner.py:367, in _panic_or_proceed(futs, timeout_exc_cls, panic)
#     365 # raise the exception
#     366 if panic:
# --> 367     raise exc
#     368 else:
#     369     return
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langgraph/pregel/executor.py:70, in BackgroundExecutor.done(self, task)
#      68 def done(self, task: concurrent.futures.Future) -> None:
#      69     try:
# ---> 70         task.result()
#      71     except GraphInterrupt:
#      72         # This exception is an interruption signal, not an error
#      73         # so we don't want to re-raise it on exit
#      74         self.tasks.pop(task)
#
# File ~/.asdf/installs/python/3.12.7/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.asdf/installs/python/3.12.7/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.asdf/installs/python/3.12.7/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, writer)
#      38 task.writes.clear()
#      39 # run the task
# ---> 40 task.proc.invoke(task.input, config)
#      41 # if successful, end
#      42 break
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langgraph/utils/runnable.py:410, in RunnableSeq.invoke(self, input, config, **kwargs)
#     408 context.run(_set_config_context, config)
#     409 if i == 0:
# --> 410     input = context.run(step.invoke, input, config, **kwargs)
#     411 else:
#     412     input = context.run(step.invoke, input, config)
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langgraph/utils/runnable.py:184, in RunnableCallable.invoke(self, input, config, **kwargs)
#     182 else:
#     183     context.run(_set_config_context, config)
# --> 184     ret = context.run(self.func, input, **kwargs)
#     185 if isinstance(ret, Runnable) and self.recurse:
#     186     return ret.invoke(input, config)
#
# Cell In[4], line 31, in supervisor_node(state)
#      27 def supervisor_node(state: AgentState) -> AgentState:
#      28     messages = [
#      29         {"role": "system", "content": system_prompt},
#      30     ] + state["messages"]
# ---> 31     response = llm.with_structured_output(Router).invoke(messages)
#      32     next_ = response["next"]
#      33     if next_ == "FINISH":
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langchain_google_vertexai/chat_models.py:1809, in ChatVertexAI.with_structured_output(self, schema, include_raw, method, **kwargs)
#    1806     llm: Runnable = self
#    1808 else:
# -> 1809     tool_name = _get_tool_name(schema)
#    1810     if isinstance(schema, type) and is_basemodel_subclass(schema):
#    1811         parser = PydanticToolsParser(tools=[schema], first_tool_only=True)
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langchain_google_vertexai/chat_models.py:1979, in _get_tool_name(tool)
#    1978 def _get_tool_name(tool: _ToolType) -> str:
# -> 1979     vertexai_tool = _format_to_gapic_tool([tool])
#    1980     return [f.name for f in vertexai_tool.function_declarations][0]
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langchain_google_vertexai/functions_utils.py:321, in _format_to_gapic_tool(tools)
#     319             gapic_tool.retrieval = gapic.Retrieval(tool["retrieval"])
#     320     else:
# --> 321         fd = _format_to_gapic_function_declaration(tool)
#     322         gapic_tool.function_declarations.append(fd)
#     323 return gapic_tool
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langchain_google_vertexai/functions_utils.py:256, in _format_to_gapic_function_declaration(tool)
#     254     return _format_pydantic_to_function_declaration(tool)
#     255 elif callable(tool):
# --> 256     return _format_base_tool_to_function_declaration(callable_as_lc_tool()(tool))
#     257 elif isinstance(tool, vertexai.FunctionDeclaration):
#     258     return _format_vertex_to_function_declaration(tool)
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langchain_core/tools/convert.py:332, in tool.<locals>._partial(func)
#     330 name_ = func.get_name() if isinstance(func, Runnable) else func.__name__
#     331 tool_factory = _create_tool_factory(name_)
# --> 332 return tool_factory(func)
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langchain_core/tools/convert.py:249, in tool.<locals>._create_tool_factory.<locals>._tool_factory(dec_func)
#     246     description = None
#     248 if infer_schema or args_schema is not None:
# --> 249     return StructuredTool.from_function(
#     250         func,
#     251         coroutine,
#     252         name=tool_name,
#     253         description=description,
#     254         return_direct=return_direct,
#     255         args_schema=schema,
#     256         infer_schema=infer_schema,
#     257         response_format=response_format,
#     258         parse_docstring=parse_docstring,
#     259         error_on_invalid_docstring=error_on_invalid_docstring,
#     260     )
#     261 # If someone doesn't want a schema applied, we must treat it as
#     262 # a simple string->string function
#     263 if dec_func.__doc__ is None:
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langchain_core/tools/structured.py:176, in StructuredTool.from_function(cls, func, coroutine, name, description, return_direct, args_schema, infer_schema, response_format, parse_docstring, error_on_invalid_docstring, **kwargs)
#     173 name = name or source_function.__name__
#     174 if args_schema is None and infer_schema:
#     175     # schema name is appended within function
# --> 176     args_schema = create_schema_from_function(
#     177         name,
#     178         source_function,
#     179         parse_docstring=parse_docstring,
#     180         error_on_invalid_docstring=error_on_invalid_docstring,
#     181         filter_args=_filter_schema_args(source_function),
#     182     )
#     183 description_ = description
#     184 if description is None and not parse_docstring:
#
# File ~/.cache/pypoetry/virtualenvs/helloworld-Q6X4IgaP-py3.12/lib/python3.12/site-packages/langchain_core/tools/base.py:238, in create_schema_from_function(model_name, func, filter_args, parse_docstring, error_on_invalid_docstring, include_injected)
#     210 def create_schema_from_function(
#     211     model_name: str,
#     212     func: Callable,
#    (...)
#     217     include_injected: bool = True,
#     218 ) -> type[BaseModel]:
#     219     """Create a pydantic schema from a function's signature.
#     220
#     221     Args:
#    (...)
#     236         A pydantic model with the same arguments as the function.
#     237     """
# --> 238     sig = inspect.signature(func)
#     240     if _function_annotations_are_pydantic_v1(sig, func):
#     241         validated = validate_arguments_v1(func, config=_SchemaConfig)  # type: ignore
#
# File ~/.asdf/installs/python/3.12.7/lib/python3.12/inspect.py:3341, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3339 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3340     """Get a signature object for the passed callable."""
# -> 3341     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3342                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/.asdf/installs/python/3.12.7/lib/python3.12/inspect.py:3081, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3077 @classmethod
#    3078 def from_callable(cls, obj, *,
#    3079                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3080     """Constructs Signature for the given callable object."""
# -> 3081     return _signature_from_callable(obj, sigcls=cls,
#    3082                                     follow_wrapper_chains=follow_wrapped,
#    3083                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/.asdf/installs/python/3.12.7/lib/python3.12/inspect.py:2612, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2610 call = _signature_get_user_defined_method(type(obj), '__call__')
#    2611 if call is not None:
# -> 2612     return _get_signature_of(call)
#    2614 new = _signature_get_user_defined_method(obj, '__new__')
#    2615 init = _signature_get_user_defined_method(obj, '__init__')
#
# File ~/.asdf/installs/python/3.12.7/lib/python3.12/inspect.py:2662, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2660             return sigcls.from_callable(object)
#    2661         else:
# -> 2662             raise ValueError(
#    2663                 'no signature found for builtin type {!r}'.format(obj))
#    2665 else:
#    2666     # An object with __call__
#    2667     call = getattr_static(type(obj), '__call__', None)
#
# ValueError: no signature found for builtin type <class 'dict'>
